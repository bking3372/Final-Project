# %%
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
database_path = "Resources/FPA_FOD_20170508.sqlite"

# %%
# Create Engine
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# %%
# Query All Records in the the Database
data = pd.read_sql("SELECT * FROM Fires", conn)

# %%
data.head()
# Out:
#    OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0         1       1  FS-1418826                FED   FS-FIRESTAT
# 1         2       2  FS-1418827                FED   FS-FIRESTAT
# 2         3       3  FS-1418835                FED   FS-FIRESTAT
# 3         4       4  FS-1418845                FED   FS-FIRESTAT
# 4         5       5  FS-1418847                FED   FS-FIRESTAT
#
#   NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  NWCG_REPORTING_UNIT_NAME  \
# 0                    FS                USCAPNF    Plumas National Forest
# 1                    FS                USCAENF  Eldorado National Forest
# 2                    FS                USCAENF  Eldorado National Forest
# 3                    FS                USCAENF  Eldorado National Forest
# 4                    FS                USCAENF  Eldorado National Forest
#
#   SOURCE_REPORTING_UNIT SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS  \
# ...

# %%
col_list = ['FOD_ID', 'SOURCE_SYSTEM_TYPE', 'FIRE_NAME', 'COMPLEX_NAME', 'FIRE_YEAR', 'DISCOVERY_DATE', 'DISCOVERY_DOY', 'DISCOVERY_TIME', 'STAT_CAUSE_CODE', 'STAT_CAUSE_DESCR', 'CONT_DATE', 'CONT_TIME', 'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE', 'LONGITUDE', 'OWNER_CODE', 'OWNER_DESCR', 'STATE', 'COUNTY', 'FIPS_CODE', 'FIPS_NAME']
df = data[col_list]

# %%
df.head(10)
# Out:
#    FOD_ID SOURCE_SYSTEM_TYPE   FIRE_NAME COMPLEX_NAME  FIRE_YEAR  \
# 0       1                FED    FOUNTAIN         None       2005
# 1       2                FED      PIGEON         None       2004
# 2       3                FED       SLACK         None       2004
# 3       4                FED        DEER         None       2004
# 4       5                FED    STEVENOT         None       2004
# 5       6                FED      HIDDEN         None       2004
# 6       7                FED        FORK         None       2004
# 7       8                FED       SLATE         None       2005
# 8       9                FED      SHASTA         None       2005
# 9      10                FED  TANGLEFOOT         None       2004
#
#    DISCOVERY_DATE  DISCOVERY_DOY DISCOVERY_TIME  STAT_CAUSE_CODE  \
# 0       2453403.5             33           1300              9.0
# 1       2453137.5            133           0845              1.0
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# FOD_ID                      0
# SOURCE_SYSTEM_TYPE          0
# FIRE_NAME              957189
# COMPLEX_NAME          1875282
# FIRE_YEAR                   0
# DISCOVERY_DATE              0
# DISCOVERY_DOY               0
# DISCOVERY_TIME         882638
# STAT_CAUSE_CODE             0
# STAT_CAUSE_DESCR            0
# CONT_DATE              891531
# CONT_TIME              972173
# FIRE_SIZE                   0
# FIRE_SIZE_CLASS             0
# LATITUDE                    0
# LONGITUDE                   0
# OWNER_CODE                  0
# OWNER_DESCR                 0
# STATE                       0
# COUNTY                 678148
# FIPS_CODE              678148
# FIPS_NAME              678148
# dtype: int64

# %%
df.dtypes
# Out:
# FOD_ID                  int64
# SOURCE_SYSTEM_TYPE     object
# FIRE_NAME              object
# COMPLEX_NAME           object
# FIRE_YEAR               int64
# DISCOVERY_DATE        float64
# DISCOVERY_DOY           int64
# DISCOVERY_TIME         object
# STAT_CAUSE_CODE       float64
# STAT_CAUSE_DESCR       object
# CONT_DATE             float64
# CONT_TIME              object
# FIRE_SIZE             float64
# FIRE_SIZE_CLASS        object
# LATITUDE              float64
# LONGITUDE             float64
# OWNER_CODE            float64
# OWNER_DESCR            object
# STATE                  object
# COUNTY                 object
# FIPS_CODE              object
# FIPS_NAME              object
# dtype: object

# %%
df = df.dropna(subset=['CONT_DATE'])

# %%
len(df)
# Out:
# 988934

# %%
df.isnull().sum(axis=0)
# Out:
# FOD_ID                      0
# SOURCE_SYSTEM_TYPE          0
# FIRE_NAME              957189
# COMPLEX_NAME          1875282
# FIRE_YEAR                   0
# DISCOVERY_DATE              0
# DISCOVERY_DOY               0
# DISCOVERY_TIME         882638
# STAT_CAUSE_CODE             0
# STAT_CAUSE_DESCR            0
# CONT_DATE              891531
# CONT_TIME              972173
# FIRE_SIZE                   0
# FIRE_SIZE_CLASS             0
# LATITUDE                    0
# LONGITUDE                   0
# OWNER_CODE                  0
# OWNER_DESCR                 0
# STATE                       0
# COUNTY                 678148
# FIPS_CODE              678148
# FIPS_NAME              678148
# DURATION               891531
# dtype: int64

# %%
df.head()
# Out:
#    FOD_ID SOURCE_SYSTEM_TYPE FIRE_NAME COMPLEX_NAME  FIRE_YEAR  \
# 0       1                FED  FOUNTAIN         None       2005
# 1       2                FED    PIGEON         None       2004
# 2       3                FED     SLACK         None       2004
# 3       4                FED      DEER         None       2004
# 4       5                FED  STEVENOT         None       2004
#
#    DISCOVERY_DATE  DISCOVERY_DOY DISCOVERY_TIME  STAT_CAUSE_CODE  \
# 0       2453403.5             33           1300              9.0
# 1       2453137.5            133           0845              1.0
# 2       2453156.5            152           1921              5.0
# 3       2453184.5            180           1600              1.0
# 4       2453184.5            180           1600              1.0
#
#   STAT_CAUSE_DESCR  ...  FIRE_SIZE_CLASS   LATITUDE   LONGITUDE OWNER_CODE  \
# 0    Miscellaneous  ...                A  40.036944 -121.005833        5.0
# ...

# %%
df.loc[:,'DURATION'] = df['CONT_DATE'] - df['DISCOVERY_DATE']
# Out:
# C:\Users\betsy_k\Anaconda3\lib\site-packages\pandas\core\indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\betsy_k\Anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df["DURATION"].describe().astype(np.int64)
# Out:
# count    988934
# mean          1
# std          15
# min           0
# 25%           0
# 50%           0
# 75%           0
# max        4018
# Name: DURATION, dtype: int64

# %%
import datetime as dt

# %%
df['DATE'] = pd.to_datetime(df['DISCOVERY_DATE'] - pd.Timestamp(0).to_julian_date(), unit='D')
df.head()
# Out:
# C:\Users\betsy_k\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    FOD_ID SOURCE_SYSTEM_TYPE FIRE_NAME COMPLEX_NAME  FIRE_YEAR  \
# 0       1                FED  FOUNTAIN         None       2005
# 1       2                FED    PIGEON         None       2004
# 2       3                FED     SLACK         None       2004
# 3       4                FED      DEER         None       2004
# 4       5                FED  STEVENOT         None       2004
#
#    DISCOVERY_DATE  DISCOVERY_DOY DISCOVERY_TIME  STAT_CAUSE_CODE  \
# 0       2453403.5             33           1300              9.0
# ...

# %%
df['MONTH'] = pd.DatetimeIndex(df['DATE']).month
df['DAY_OF_WEEK'] = df['DATE'].dt.weekday
df.head()
# Out:
# C:\Users\betsy_k\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\betsy_k\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    FOD_ID SOURCE_SYSTEM_TYPE FIRE_NAME COMPLEX_NAME  FIRE_YEAR  \
# 0       1                FED  FOUNTAIN         None       2005
# 1       2                FED    PIGEON         None       2004
# ...

# %%
#export final file
output_data_file = "Resources/wildfires.csv"

# %%
df.to_csv(output_data_file, index=False, header=True)
